# %% [markdown]
# # Viewing PDF
#
# This is not a very successful endeavour

# %%
from pdfminer.high_level import extract_text

# Specify the path to your PDF file
pdf_path = r"C:\Users\THW_9\Desktop\deskyop\Housing Research LKO\Qualtrics\Housing Policy Data\Git\ScrapingHDB\ScrapingHDBApplications\HDB Brochures\champions-bliss.pdf"

# Extract text from page 9
text = extract_text(pdf_path, page_numbers=[8])

# Split the text into lines
lines = text.split("\n")

# Parse lines into a table (assuming tabular data is separated by spaces or tabs)
table = [line.split() for line in lines]

# Print the parsed table
print("Parsed Table from Page 9:")
for row in table:
    print(row)
# Out:
# Parsed Table from Page 9:
# ['INNOVA']
# ['PRIMARY']
# ['SCHOOL']
# []
# ['PUBLIC']
# ['HOUSING', '(U/C)']
# []
# ['568A']
# []
# ['9']
# []
# ['3']
# []
# ['5']
# []
# ['EXISTING']
# ['PUBLIC']
# ['HOUSING']
# []
# ['0']
# ['4']
# ['5']
# []
# ['W']
# []
# ['O']
# []
# ['O']
# []
# ['D']
# []
# ['L']
# []
# ['A']
# []
# ['N']
# []
# ['D']
# []
# ['S']
# []
# ['E']
# []
# ['ESS']
# ['563']
# []
# ['PP']
# ['562']
# []
# ['DOP']
# []
# ['X']
# []
# ['A']
# []
# ['B']
# []
# ['A']
# []
# ['I']
# []
# ['S']
# []
# ['V']
# []
# ['Y']
# []
# ['T']
# ['I']
# []
# ['E']
# []
# ['&']
# []
# ['N']
# []
# ['N']
# []
# ['G']
# []
# ['S']
# []
# ['U']
# []
# ['H']
# []
# ['B']
# []
# ['E']
# []
# ['E']
# []
# ['U']
# []
# ['L']
# []
# ['S']
# []
# ['T']
# []
# ['E']
# []
# ['R']
# []
# ['AFS']
# []
# ['S']
# []
# ['HC']
# []
# ['T']
# []
# ['P']
# []
# ['G']
# []
# ['1']
# []
# ['158']
# []
# ['562C']
# []
# ['160']
# []
# ['170']
# []
# ['162']
# []
# ['168']
# []
# ['S']
# []
# ['EFS']
# []
# ...

# %%
text
# Out:
# "INNOVA\nPRIMARY\nSCHOOL\n\nPUBLIC\nHOUSING (U/C)\n\n568A\n\n9\n\n3\n\n5\n\nEXISTING\nPUBLIC\nHOUSING\n\n0\n4\n5\n\nW\n\nO\n\nO\n\nD\n\nL\n\nA\n\nN\n\nD\n\nS\n\nE\n\nESS\n563\n\nPP\n562\n\nDOP\n\nX\n\nA\n\nB\n\nA\n\nI\n\nS\n\nV\n\nY\n\nT\nI\n\nE\n\n&\n\nN\n\nN\n\nG\n\nS\n\nU\n\nH\n\nB\n\nE\n\nE\n\nU\n\nL\n\nS\n\nT\n\nE\n\nR\n\nAFS\n\nS\n\nHC\n\nT\n\nP\n\nG\n\n1\n\n158\n\n562C\n\n160\n\n170\n\n162\n\n168\n\nS\n\nEFS\n\n164\n\n166\n\nSITE RESERVED FOR FUTURE\nHIGH-RISE RESIDENTIAL\nDEVELOPMENT\n\nC HA M PIO NS                                 W AY (U/C)\n\n1\n\n5\n\n6\n\n1\n\n5\n\n4\n\n1\n\n4\n\n0\n\n1\n\n4\n\n6\n\n1\n\n4\n\n8\n\n1\n\n5\n\n0\n\n1\n\n5\n\n2\n\n1\n\n3\n\n8\n\n1\n\n3\n\n6\n\nF\n\n1\n\n4\n\n2\n\n1\n\n4\n\n4\n\nT\n\nPG\n\nA\n\n5\n\n6\n\n2\n\nB\n\n1\n\n2\n\n6\n\n1\n\n3\n\n4\n\n1\n\n3\n\n2\n\n1\n\n2\n\n8\n\n1-S\n\nF\n\nT\n\nU\n\nO\n\nT\n\nU\n\nR\n\nM\n\nF\n\nE\n\nA\n\nR\n\nNITIE\nCILITIE\nS/\n\n6\n\n1\n\nE\n\nA\n\nS\n\n5\n\nE\n\nY\n\nACE THE PLACE\nCOMMUNITY\nCLUB\n\nT\n\nA\n\
# ...

# %%
from pdfminer.high_level import extract_text

# Specify the path to your PDF file

pdf_path = r"C:\Users\THW_9\Desktop\deskyop\Housing Research LKO\Qualtrics\Housing Policy Data\Git\ScrapingHDB\ScrapingHDBApplications\HDB Brochures\garden-vale-@-tengah.pdf"

# Extract text from page 9
text = extract_text(pdf_path, page_numbers=[8])

# Split the text into lines
lines = text.split("\n")

# Parse lines into a table (assuming tabular data is separated by spaces or tabs)
table = [line.split() for line in lines]

# Print the parsed table
print("Parsed Table from Page 9:")
for row in table:
    print(row)
# Out:
# Parsed Table from Page 9:
# []

# %%
text
# Out:
# '\x0c'

# %%
import pdfplumber

# Specify the path to your PDF file
pdf_path = r"C:\Users\THW_9\Desktop\deskyop\Housing Research LKO\Qualtrics\Housing Policy Data\Git\ScrapingHDB\ScrapingHDBApplications\HDB Brochures\champions-bliss.pdf"

# Open the PDF
with pdfplumber.open(pdf_path) as pdf:
    for page in pdf.pages:
        # Extract tables from the page
        tables = page.extract_tables()
        for table in tables:
            print(table)  # Each table is a list of rows
# Out:
# [['', '', ''], [None, '', None], [None, '', None]]
# [['', '']]
# [['', '']]
# [['2-room Flexi\n4-room\nAvailable either on a 99-year lease or short-lease', None], ['Floor tiles in the:\n● household shelter\n● bathroom\n● kitchen\nWall tiles in the:\n● bathroom\n● kitchen\nA sliding partition/ door for the bedroom\nand folding bathroom door\nGrab bars\n(for 2-room Flexi flats on short-leases)', 'Floor tiles in the:\n● household shelter\n● bathrooms\n● kitchen, service yard\nWall tiles in the:\n● bathrooms\n● kitchen']]
# [['P U B L I C 140\nH O U S I NG (U/C)\n138 1\n144\n562B\n136\n568A\n134\nFA/F\n13\nW\nO\nO\nD\nL\nA\nN\nD\nS\nSINGAPORE D\nRI\nSPORTS V\nSCHOOL E', None], [None, 'S H E B L U T S B A T U Y R E']]
# [['Total', '', '38', '112', '199', '349', '']]
# ...

# %%
import pdfplumber

# Specify the path to your PDF file
#pdf_path = r"C:\Users\THW_9\Desktop\deskyop\Housing Research LKO\Qualtrics\Housing Policy Data\Git\ScrapingHDB\ScrapingHDBApplications\HDB Brochures\champions-bliss.pdf"
pdf_path = r"C:\Users\THW_9\Desktop\deskyop\Housing Research LKO\Qualtrics\Housing Policy Data\Git\ScrapingHDB\ScrapingHDBApplications\HDB Brochures\garden-vale-@-tengah.pdf"
# Open the PDF
with pdfplumber.open(pdf_path) as pdf:
    # Access page 9 (index starts from 0, so page 9 is index 8)
    page_9 = pdf.pages[14]
    
    # Extract text from page 9
    text = page_9.extract_text()
    print("Text from page 9:")
    print(text)
    
    # Extract tables from page 9
    tables = page_9.extract_tables()
    print("\nTables from page 9:")
    for table in tables:
        print(table)  # Each table is a list of rows
# Out:
# Text from page 9:
# LEGEND
# LEGEND
# LEGEND
# LEGEND
# LEGEND
# N B u l m oc b k er o N f S um to b re e y r s ( 2 T F y R l p e o e x o i m 1) ( 2 T F y R l p e o e x o i m 2) 3 Room 4 Room 5 Room Total Lifts Opens At
# 228A 7/11/14 Every storey
# 228B 10/14 Every storey
# 229A 7/11/14 Every storey
# 229B 11/14 Every storey
# 230A 7/11/14 Every storey
# 230B 11/14 Every storey
# 231A 7/11/14 Every storey
# 231B 11/14 Every storey
# TOTAL 130 334 91 220 212 987
# N
# GARDEN VALE @ TENGAH
# Block Number 2 Room 2 Room
# Number of Storeys Flexi Flexi 3 Room 4 Room 5 Room Total Lifts Opens At
# (Type 1) (Type 2)
# 228A 7/11/14 Every storey
# 228B 10/14 Every storey
# 229A 7/11/14 Every storey
# 229B 11/14 Every storey
# 230A 7/11/14 Every storey
# 230B 11/14 Every storey
# 231A 7/11/14 Every storey
# 231B 11/14 Every storey
# TOTAL 130 334 91 220 212 987
# ...

# %%
import pdfplumber

# Specify the path to your PDF file
pdf_path = r"C:\Users\THW_9\Desktop\deskyop\Housing Research LKO\Qualtrics\Housing Policy Data\Git\ScrapingHDB\ScrapingHDBApplications\HDB Brochures\champions-bliss.pdf"
#pdf_path = r"C:\Users\THW_9\Desktop\deskyop\Housing Research LKO\Qualtrics\Housing Policy Data\Git\ScrapingHDB\ScrapingHDBApplications\HDB Brochures\garden-vale-@-tengah.pdf"
# Open the PDF
with pdfplumber.open(pdf_path) as pdf:
    # Access page 9 (index starts from 0, so page 9 is index 8)
    page_9 = pdf.pages[8]
    
    # Extract text from page 9
    text = page_9.extract_text()
    print("Text from page 9:")
    print(text)
    
    # Extract tables from page 9
    tables = page_9.extract_tables()
    print("\nTables from page 9:")
    for table in tables:
        print(table)  # Each table is a list of rows
# Out:
# Text from page 9:
# INNOVA 539
# PRIMARY
# SCHOOL
# 4 LEGEND
# 4
# 5
# 2-Room Flexi (Type 1)
# EXISTING
# PUBLIC 2-Room Flexi (Type 2)
# 0
# HOUSING 5 4 4-Room
# W
# O
# C) O Surrounding Buildings / Structures
# SITE RESERVED FOR FUTURE Y (
# U/ D
# L A Reserved for Development / Existing Development
# H D I E G V H E - L R O IS P E M R E E N S T IDENTIAL
# H A M
# PI
# O N S
# W A
# 156 158
# DOP
# 5 E 6 S 3
# A
# S
# FS 5 P 6 P 2 S HC T
# N D S
# B A Y E & X I S S H TI E N A L G T V E B E R U N S U E
# 1
# 541 F E
# E
# D
# P C
# T
# a
# r
# l
# l
# a
# r
# h d
# e
# e
# o
# c v i e
# c
# l
# l
# p
# i i d
# l
# l
# t
# l
# i
# r i
# -
# i
# s
# r
# r t l o
# o
# y
# i
# i e
# c
# e n
# (
# f
# n
# a
# T
# F
# f
# s (
# l
# P
# )
# i P P t
# S
# n
# o
# l P a e
# u
# rc
# ) y s
# b
# /
# h
# g s
# -
# L
# S
# r
# (
# S o i
# t
# D
# n
# a
# u t k a
# O
# t
# n b
# i
# t
# o
# d i
# P
# r o
# n
# i
# )
# d ( n P
# (
# g
# /
# E
# ( G e
# L
# E
# S
# i
# ) F
# n
# (
# S
# L /
# k
# ...
